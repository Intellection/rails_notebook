# %%
ls -i Rails

# %%
Rails.application.assets

# %%
Rails.application.routes

# %%
Rails.application.class.superclass

# %%
Rails.application
# Out:
# SystemStackError: stack level too deep
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:188:in `block (3 levels) in expanded'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:188:in `map'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:188:in `block (2 levels) in expanded'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:187:in `chdir'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:187:in `block in expanded'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:158:in `each'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:158:in `each'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/railties-4.2.5/lib/rails/paths.rb:183:in `expanded'
# /Users/brendon/.rvm/gems/ruby-2.2.1/gems/activesupport-4.2.5/lib/active_support/core_ext/object/json.rb:128:in `as_json'
# ...

# %%
Rails.application.config.app_generators

# %%
Pry::Command::Ls::LsEntity.new(interrogatee: {}, no_user_opts: true, opts: {}, args: {}, _pry_: _pry_).entities_table
